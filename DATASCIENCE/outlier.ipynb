# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

data=np.array([250,275,300,320,325,330,350,360,1111111111111111111])

# %%
z_scores = np.abs(stats.zscore(data))
z_scores
# Out:
# array([0.35355339, 0.35355339, 0.35355339, 0.35355339, 0.35355339,
#        0.35355339, 0.35355339, 0.35355339, 2.82842712])

# %%
threshold=3

# %%
outliers = np.where(z_scores > threshold)[0]
print("outliers:",outliers)
# Out:
# outliers: []

# %%
outliers
# Out:
# array([8], dtype=int64)

# %%
data[8]
# Out:
# 100000

# %%
plt.scatter(np.arange(len(data)), data, color='red', label='Actual data')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
